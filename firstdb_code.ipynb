# %%
print("I am creating a notebook which will run on databricks platform, job started")

# %%
a = 1
b = 2
print(a + b)
print(a - b)
print(a * b)
print(a / b)

# %%
print("end of the file, job completed")

# %%
print("hello databrics")

# %%
print("hey i am trying to clone git with databricks")
